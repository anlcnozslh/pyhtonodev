# %%
def nothesaplama(vize,final,proje):
    sonuç = vize*0.3 + final*0.5 + proje*0.2
    return sonuç

def notsonuç(total):
    if 90 <= total:
        print("Harf Notunuz AA Geçtiniz Tebrikler")
    elif 70 <= total < 90:
        print("Harf Notunuz BB Geçtiniz Tebrikler")
    elif 50 <= total < 70:
        print("Harf Notunuz CC Geçtiniz Tebrikler")
    elif 30 <= total < 50:
        print("Harf Notunuz DD Geçtiniz Tebrikler")
    else:
        print("Harf Notunuz FF Geçtiniz Tebrikler")
        
class Öğrenci():
    dersnot = {}
   
    
    def __init__(self,name):
        self.name = name
        
    def dersTanimla(self,dersinadi,vize,final,proje):
        self.dersinadi=dersinadi
        self.vize=vize
        self.final=final
        self.proje=proje
        self.dersnot[self.dersinadi]=[self.vize,self.final,self.proje]
          
    def derslerigöster(self):
        for x in self.dersnot.keys():
            print(x)
    
        
        
    

name = "Anıl Can Özsalih"

dersler = {1:"Fizik",2:"Matematik",3:"Sosyal Bilimler",4:"Kimya",5:"Türkçe",6:"Müzik",7:"Felsefe",8:"Din"}

a = 3

while a > 0:
    name_input = input("İsminizi Giriniz: ")
    
    if name_input == name:
        print("Giriş Yapılıyor...")
        break
    else:
        print("Tekrar Deneyiniz!!!")
        a = a-1
        
if a != 0:
    student = Öğrenci(name)
    print("***********************************")
    print("Öğrenci Bilgi Sistemine Hoşgeldiniz")
    print("*********************************")
    print("Seçebilceğiniz dersler bunlardır")
    print(dersler)
    x = int(input("Kaç Ders seçmek istiyorsunuz: "))
    
    if 3 <= x <= 5:
        z = 0
        while z < x:
            isim = input("Ders ismini giriniz")
            vize = int(input("Vize Notunu Giriniz:"))
            final = int(input("Final Notunu Giriniz"))
            proje = int(input("Proje Notunu Giriniz: "))
            student.dersTanimla(isim,vize,final,proje)
    
            z += 1
    
            print(student.dersnot)
            d1 = student.dersnot.copy()
            
        for i in d1:
            m = nothesaplama(d1[i][0],d1[i][1],d1[i][2])
            print(i,"Genel Not Ortalamanız",m)
            notsonuç(m)
            
        
              
    else:
        print("minimum 3 maksimum 5 ders seçmeniz gerekiyor")
  
    
                
            
else:
    print("Yanlış Kullanıcı Bilgisi Giriniz Lütfen Daha Sonra Tekrar Deneyin")
